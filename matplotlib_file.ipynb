# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
x = [1,2,3,4,5,6]
y = [1,2,3,4,5,6]
y1 = [5,4,7,8,9,12]
gender = ['female','male','female','male','male','female']
plt.figure(figsize=(5,3))
plt.plot(x,y,color='blue',marker='*',linestyle = 'solid',label = 'Product A')
plt.plot(x,y1,color='red',marker='o',linestyle = 'dashed',label = 'Product B')
plt.grid(True)
plt.legend()
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Line plot")
plt.show()

# %%
plt.scatter(x,y1,color = 'red',marker = 'o')
plt.grid(True)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Line plot")
plt.show()

# %%
# x_len = len(x)
# width = 0.4
# plt.bar(x_len - width/2,y,color = 'blue',width = width )
# plt.bar(x_len + width/2,y1,color = 'red',width = width)
# plt.show()
# sns.barplot(x = 'x' ,y = 'y' ,hue = "gender")
# plt.show()

# %%
# data from https://allisonhorst.github.io/palmerpenguins/

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

species = ("Adelie", "Chinstrap", "Gentoo")
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)

plt.show()

# %%
data = [1,2,3,2,5,1,8,6,9,2,5,5,2,3]
plt.figure(figsize=(5,3))
plt.hist(data,color = "purple",bins = 12)
plt.title("Histogram")
plt.xlabel("value")
plt.ylabel("frequence")
plt.show()

# %%
salary  = [15000,23000,70000,50000]
label = ['Intern','Employee','senior','manager']

plt.pie(salary,labels  = label,colors = ['red','yellow','green','blue'],autopct='%2.2f%%')
plt.legend()
plt.title("Pie chart")
plt.show()

# %%
data = [1,2,3,4,5,6,7,8,9,20]
plt.boxplot(data)
plt.title('Box Plot')
plt.xlabel("outlier plot")
plt.ylabel("values")
plt.show()

# %%
import seaborn as sns

# %%
days = [i for i in range(1,16)]
temperature = [j  for j in range(32,47)]

temp_df = pd.DataFrame({"days":days,"temperature":temperature})

# %%
temp_df
# Out:
#     days  temperature
# 0      1           32
# 1      2           33
# 2      3           34
# 3      4           35
# 4      5           36
# 5      6           37
# 6      7           38
# 7      8           39
# 8      9           40
# 9     10           41
# 10    11           42
# 11    12           43
# 12    13           44
# 13    14           45
# 14    15           46

# %%
sns.lineplot(x = "days",y = "temperature",data = temp_df)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
tips_df = sns.load_dataset('tips')

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(x = "total_bill",y = "tip",data = tips_df)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.lineplot(x = "size",y = "total_bill",data = tips_df,hue = 'sex',style = "day",palette = "magma",markers = ["o","<",">","*"] )
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(

# %%
sns.distplot(tips_df['total_bill'],hist = True,color = 'r',bins = 100)
plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_8292\1177036392.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['total_bill'],hist = True,color = 'r',bins = 100)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
hue_order = ['Male','Female']
sns.barplot(x = 'day',y = 'total_bill',data = tips_df,hue = "sex",hue_order = hue_order)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.scatterplot(x = 'total_bill',y = 'tip',data = tips_df,hue = "sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize = (10,8))
sns.scatterplot(x=  "total_bill",y = "tip",data = tips_df,hue = "sex")
# sns.lineplot(x = "total_bill",y = "tip",data = tips_df,color = "red")
sns.barplot(x = "total_bill",y = "tip",data = tips_df)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.arange(1, 6)  # X-axis values
y1 = [10, 20, 30, 40, 50]  # Y-axis 1 values
y2 = [100, 90, 80, 70, 60]  # Y-axis 2 values

# Create figure and axis
fig, ax1 = plt.subplots()

# Plot data for the first y-axis
ax1.bar(x, y1, color='b', width=0.4, label='Y1 Data')  # Bar graph for Y1
ax1.set_xlabel('X-axis')  # Label for X-axis
ax1.set_ylabel('Y1-axis', color='b')  # Label for Y1-axis
ax1.tick_params(axis='y', labelcolor='b')  # Tick color for Y1-axis
ax1.legend(loc='upper left')

# Create second y-axis
ax2 = ax1.twinx()  # Create a twin y-axis
ax2.bar(x + 0.4, y2, color='r', width=0.4, label='Y2 Data')  # Bar graph for Y2
ax2.set_ylabel('Y2-axis', color='r')  # Label for Y2-axis
ax2.tick_params(axis='y', labelcolor='r')  # Tick color for Y2-axis
ax2.legend(loc='upper right')

# Show the plot
plt.title("Bar Graph with Two Y Axes")
plt.show()
